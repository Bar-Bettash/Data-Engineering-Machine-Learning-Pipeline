# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from DataCleaning import fill_null_ML

# %%
df = pd.read_csv("../data/youtube_trending.csv")

# %%
# check for missing values
print(df.isnull().sum()[df.isnull().sum()>0])
# Out:
# trending_date              466
# title                      466
# channel_title              466
# category_id                466
# publish_time               466
# tags                       466
# views                      466
# likes                      466
# dislikes                   466
# comment_count              466
# thumbnail_link             466
# comments_disabled          466
# ratings_disabled           466
# video_error_or_removed     466
# description               1036
# dtype: int64

# %%
fill_null_ML(df, model_dir='impute_models')
# Out:
# 🚀 Starting ML-based imputation (only for float, int, object)...
#
# Training model to impute: trending_date

# %%
num_cols = df.select_dtypes(include=['number']).columns
imputer = KNNImputer(n_neighbors=3)
df[num_cols] = imputer.fit_transform(df[num_cols])

# %%
sns.boxplot(x='category_id', y='views', data=df)
plt.title('Views per Category')
plt.show()
